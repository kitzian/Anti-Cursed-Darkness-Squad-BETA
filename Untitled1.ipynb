# %% [markdown]
# <a href="https://colab.research.google.com/github/kitzian/Anti-Cursed-Darkness-Squad-BETA/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd Anti-Cursed-Darkness-Squad-BETA
# Out:
# /content/Anti-Cursed-Darkness-Squad-BETA

# %%
# !git clone https://github.com/Z3NTL3/Anti-Cursed-Darkness-Squad-BETA
# Out:
# Cloning into 'Anti-Cursed-Darkness-Squad-BETA'...
# remote: Enumerating objects: 1177, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 1177 (delta 10), reused 2 (delta 2), pack-reused 1152
# Receiving objects: 100% (1177/1177), 96.16 MiB | 41.34 MiB/s, done.
# Resolving deltas: 100% (649/649), done.

# %%
# !python3 installer.py
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [62.2 kB]
# ...

# %%
ls
# Out:
# bypasses/     flood.js      node_modules/      start.py
# cf-bypass.js  haven*        package.json       ua.txt
# client.js     header.txt    package-lock.json  udp
# cocorisss.pl  home.png      panel.png          version3.png
# darkness*     httpflood     privacypass.json   website-nuker.js
# design3.png   HTTP-RAW.js   proxies.txt        website-nuker-proxied.js
# files/        installer.py  random-words.js
# fivemovh      menu.png      README.md
# fixer*        method.js     requirements.txt

# %%
cd Anti-Cursed-Darkness-Squad-BETA
# Out:
# /content/Anti-Cursed-Darkness-Squad-BETA

# %%
# !ulimit -n 999999

# %%
# !sudo ./darkness
# Out:
#         ╔═╗╔╗╔╔╦╗╦       ╔═╗╦ ╦╦═╗╔═╗╔═╗╔╦╗
#         ╠═╣║║║ ║ ║  ───  ║  ║ ║╠╦╝╚═╗║╣  ║║
#         ╩ ╩╝╚╝ ╩ ╩       ╚═╝╚═╝╩╚═╚═╝╚═╝═╩╝
#     ╔╦╗╔═╗╦═╗╦╔═╔╗╔╔═╗╔═╗╔═╗  ╔═╗╔═╗ ╦ ╦╔═╗╔╦╗
#      ║║╠═╣╠╦╝╠╩╗║║║║╣ ╚═╗╚═╗  ╚═╗║═╬╗║ ║╠═╣ ║║
#     ═╩╝╩ ╩╩╚═╩ ╩╝╚╝╚═╝╚═╝╚═╝  ╚═╝╚═╝╚╚═╝╩ ╩═╩╝
#
#                   Todays Date:
#                   July 11, 2021
#
#         ╔══════════════════════════════╗
#         ║  Anti-Cursed Darkness Squad  ║
#         ║   >  Software Developer:  <  ║
#         ║          z3ntl3 root         ║
#         ║           empfaked           ║
#         ╚══════════════════════════════╝
#
#
# > Version: 7 Darkness Mini
#
#
# ┌──(@root)-[/home/z3ntl3/]
# └───⮞  License: Valid [Online] + Proxies Updated!
#
# >  Type menu  to view attack commands!
#
# ┌──(@root)-[/home/z3ntl3/]
# └───⮞ proxy-crawl
#
#         ╔═╗╔╗╔╔╦╗╦       ╔═╗╦ ╦╦═╗╔═╗╔═╗╔╦╗
#         ╠═╣║║║ ║ ║  ───  ║  ║ ║╠╦╝╚═╗║╣  ║║
#         ╩ ╩╝╚╝ ╩ ╩       ╚═╝╚═╝╩╚═╚═╝╚═╝═╩╝
# ...

# %%
# !node method.js 88888888 request 20

# %%
# !ps -aux
# Out:
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# root           1  0.2  0.4 347116 57936 ?        Ssl  06:43   0:04 /tools/node/b
# root          15  0.0  0.0  35892  4760 ?        Ss   06:43   0:00 tail -n +0 -F
# root          49  0.2  0.4 195440 61748 ?        Sl   06:44   0:04 /usr/bin/pyth
# root          50  0.1  0.0 709892  8508 ?        Sl   06:44   0:03 /usr/local/bi
# root          81  0.1  0.0      0     0 ?        Z    06:44   0:02 [python3] <de
# root         118  0.0  0.0  18380   296 ?        S    06:44   0:00 /bin/bash --n
# root         119  0.0  0.1 2161736 17456 ?       Sl   06:44   0:00 /opt/google/d
# root         120  0.0  0.0  11604  2160 ?        S    06:44   0:00 grep --color=
# root         158  0.1  0.5 2434172 70608 ?       Sl   06:44   0:02 /opt/google/d
# root         177  0.0  0.0      0     0 ?        Z    06:44   0:00 [fusermount]
# root         210  0.0  0.0  18380  3044 ?        S    06:44   0:00 bash -c tail
# ...
